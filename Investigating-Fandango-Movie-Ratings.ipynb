# %% [markdown]
# <div>
#     <b>Description:</b> Investigating Fandango Movie Ratings<br>
#     <b>Author:</b> Maika Carmelle Henry Northrop
# </div>
# <br>

# %%
#import modules
import csv
from csv import reader
import pandas as pd
import pprint

# %% [markdown]
# # Investigating Fandango Movie Ratings

# %% [markdown]
# ## Are Fandango's Ratings Legit?
# On October 15, 2015, Walt Hickey from FiveThirtyEight published a [popular article](https://fivethirtyeight.com/features/fandango-movies-ratings/) where he presented strong evidence which suggest that Fandango's movie rating system was biased and dishonest.  In this project, our goal is to analyze recent movie ratings and determine whether there has been any change in Fandango's rating system after Hickey's analysis.

# %% [markdown]
# ## Understanding the Data
# We're going to work with two samples of movie ratings:
# * data collected from Hickey's analysis
# * data collected after Hickey's analysis
#
# Both datasets are stored in CSV files.  Let's explore them.

# %%
pd.options.display.max_columns = 100  # Avoid displaying truncated output

previous = pd.read_csv('datasets/fandango_score_comparison.csv')
after = pd.read_csv('datasets/movie_ratings_16_17.csv')

previous.head(3)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
#
#    RT_norm  RT_user_norm  Metacritic_norm  Metacritic_user_nom  IMDB_norm  \
# 0     3.70           4.3             3.30                 3.55       3.90
# 1     4.25           4.0             3.35                 3.75       3.55
# 2     4.00           4.5             3.20                 4.05       3.90
#
#    RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# ...

# %%
after.head(3)
# Out:
#                  movie  year  metascore  imdb  tmeter  audience  fandango  \
# 0  10 Cloverfield Lane  2016         76   7.2      90        79       3.5
# 1             13 Hours  2016         48   7.3      50        83       4.5
# 2  A Cure for Wellness  2016         47   6.6      40        47       3.0
#
#    n_metascore  n_imdb  n_tmeter  n_audience  nr_metascore  nr_imdb  \
# 0         3.80    3.60       4.5        3.95           4.0      3.5
# 1         2.40    3.65       2.5        4.15           2.5      3.5
# 2         2.35    3.30       2.0        2.35           2.5      3.5
#
#    nr_tmeter  nr_audience
# 0        4.5          4.0
# 1        2.5          4.0
# 2        2.0          2.5
